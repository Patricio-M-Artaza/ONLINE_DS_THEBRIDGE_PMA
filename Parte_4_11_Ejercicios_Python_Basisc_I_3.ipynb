# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## EJERCICIOS PYTHON BASICO 3:
# ## Operaciones matemáticas, comparación y booleanas

# %% [markdown]
# Completa los siguiente ejercicios, la solución completa a los mismos se publicarán en el repo del curso a lo largo del sprint. En algunos ejercicios se muestra la solución final, para que puedas comprobar que lo has hecho bien, pero lo importante es el código que generes. ¡Vaaamos, a ello...!

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
#
# ## Ejercicio 1
# Tenemos las siguientes variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Comprueba:
# 1. Si A y B son equivalentes
# 2. Si A y C NO son equivalentes
# 3. Si A es mayor que C
# 4. Si C es menor o igual que A
# 5. Si B NO es equivalente a C

# %%
A = 4
B = "Text"
C = 4.1

print("1:", A == B)
print("2:", A != C)
print("3:", A > C)
print("4:", C <= A)
print("5:", B != C)
# Out:
# 1: False
# 2: True
# 3: False
# 4: False
# 5: True

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 2
# Crea un programa donde se recojan dos inputs del usuario, y el output del programa sea si esos inputs son iguales o no

# %%
valor1 = input("Ingresa el primer valor:")
valor2 = input("Ingresa el segundo valor:")

print("Los valores son iguales?", valor1 == valor2)
# Out:
# Ingresa el primer valor: 1
# Ingresa el segundo valor: 1
# Los valores son iguales? True

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 3
# Mismo programa que en 2, pero en esta ocasión tienen que ser tres inputs y dos salidas. Una de las salidas que nos indique si todos son iguales, y la otra si al menos dos inputs sí que lo son

# %%
valor1 = input("Ingresa el primer valor:")
valor2 = input("Ingresa el segundo valor:")
valor3 = input("Ingresa el tercer valor:")

print("Los valores son iguales?", valor1 == valor2 == valor3)
print("Los valores son iguales?", (valor1 == valor2) or (valor3 == valor1) or (valor2 == valor3))
# Out:
# Ingresa el primer valor: hola
# Ingresa el segundo valor: hola
# Ingresa el tercer valor: hola
# Los valores son iguales? True
# Los valores son iguales? True

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 4
# Razona sin ejecutar código el output que obtendremos de las siguientes sentencias
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True
